# %%
import pandas as pd
import numpy as np
import os
import psycopg2 as pg2
from sqlalchemy import create_engine

pd.options.display.max_columns = 999
pd.options.display.max_rows = 999

# %%
HOST = 'postgres'
USER = os.getenv('POSTGRES_USER')
PASSWORD = os.getenv('POSTGRES_PASSWORD')
DB = os.getenv('POSTGRES_DB')
PORT = os.getenv('POSTGRES_PORT')

assert HOST and USER and PASSWORD and DB and PORT

# %%
url = f'postgresql://{USER}:{PASSWORD}@{HOST}:{PORT}/{DB}' 
engine = create_engine(url)

con = pg2.connect(host=HOST,
                  user=USER,
                  password=PASSWORD,
                  database=DB)
con.autocommit = True
cur = con.cursor()

# %%
def select(sql):
    return pd.read_sql(sql, engine)

# %%
sql = '''SELECT *
FROM pg_catalog.pg_tables
WHERE schemaname != 'pg_catalog' AND 
    schemaname != 'information_schema';'''
select(sql)
# Out:
#    schemaname                 tablename tableowner tablespace  hasindexes  \
# 0      public                test_table       user       None        True
# 1      public                  datasets       user       None        True
# 2      public                    inputs       user       None        True
# 3      public                input_tags       user       None        True
# 4      public            model_versions       user       None        True
# 5      public                trace_info       user       None        True
# 6      public                trace_tags       user       None        True
# 7      public    trace_request_metadata       user       None        True
# 8      public                      runs       user       None        True
# 9      public               experiments       user       None        True
# 10     public                      tags       user       None        True
# 11     public                   metrics       user       None        True
# 12     public                    params       user       None        True
# 13     public           alembic_version       user       None        True
# 14     public           experiment_tags       user       None        True
# 15     public            latest_metrics       user       None        True
# 16     public         registered_models       user       None        True
# 17     public     registered_model_tags       user       None        True
# 18     public        model_version_tags       user       None        True
# 19     public  registered_model_aliases       user       None        True
#
#     hasrules  hastriggers  rowsecurity
# 0      False        False        False
# 1      False         True        False
# 2      False        False        False
# 3      False        False        False
# 4      False         True        False
# 5      False         True        False
# 6      False         True        False
# 7      False         True        False
# 8      False         True        False
# 9      False         True        False
# 10     False         True        False
# 11     False         True        False
# 12     False         True        False
# 13     False        False        False
# 14     False         True        False
# 15     False         True        False
# 16     False         True        False
# 17     False         True        False
# 18     False         True        False
# 19     False         True        False

# %%
sql = '''SELECT * FROM test_table'''
tmp = select(sql)
tmp
# Out:
#    id  integer_column  bigint_column  smallint_column  real_column  \
# 0   1             123     1234567890            32767       123.45
#
#    double_column char_column varchar_column text_column date_column  \
# 0        123.456  Some Char    Some Varchar   Some Text  2023-10-25
#
#   time_column    timestamp_column  boolean_column
# 0    13:45:00 2023-10-25 13:45:00            True

# %%
tmp.dtypes
# Out:
# id                           int64
# integer_column               int64
# bigint_column                int64
# smallint_column              int64
# real_column                float64
# double_column              float64
# char_column                 object
# varchar_column              object
# text_column                 object
# date_column                 object
# time_column                 object
# timestamp_column    datetime64[ns]
# boolean_column                bool
# dtype: object

# %%
tmp.columns
# Out:
# Index(['id', 'integer_column', 'bigint_column', 'smallint_column',
#        'real_column', 'double_column', 'char_column', 'varchar_column',
#        'text_column', 'date_column', 'time_column', 'timestamp_column',
#        'boolean_column'],
#       dtype='object')

# %%
cols_list = ['integer_column', 'bigint_column', 'smallint_column', 'real_column', 'double_column',
             'date_column', 'time_column', 'timestamp_column']
for col in cols_list:
    val = tmp[col][0]
    print(val, type(val))

print()
cols_list = ['char_column', 'varchar_column', 'text_column']
for col in cols_list:
    val = tmp[col][0]
    print(val, type(val), len(val))
# Out:
# 123 <class 'numpy.int64'>
# 1234567890 <class 'numpy.int64'>
# 32767 <class 'numpy.int64'>
# 123.45 <class 'numpy.float64'>
# 123.456 <class 'numpy.float64'>
# 2023-10-25 <class 'datetime.date'>
# 13:45:00 <class 'datetime.time'>
# 2023-10-25 13:45:00 <class 'pandas._libs.tslibs.timestamps.Timestamp'>
#
# Some Char  <class 'str'> 10
# Some Varchar <class 'str'> 12
# Some Text <class 'str'> 9

# %%
df = pd.read_csv('../data/winequality-red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
name = 'winequality'
df.to_sql(name, engine, if_exists='replace')
# Out:
# 599

# %%
sql = '''SELECT *
FROM pg_catalog.pg_tables
WHERE schemaname != 'pg_catalog' AND schemaname != 'information_schema';'''
select(sql)
# Out:
#   schemaname    tablename tableowner tablespace  hasindexes  hasrules  \
# 0     public   test_table       user       None        True     False
# 1     public  winequality       user       None        True     False
#
#    hastriggers  rowsecurity
# 0        False        False
# 1        False        False

# %%
sql = '''SELECT * FROM winequality'''
df = select(sql)
df
# Out:
#       index  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0         0            7.4             0.700         0.00             1.9
# 1         1            7.8             0.880         0.00             2.6
# 2         2            7.8             0.760         0.04             2.3
# 3         3           11.2             0.280         0.56             1.9
# 4         4            7.4             0.700         0.00             1.9
# ...     ...            ...               ...          ...             ...
# 1594   1594            6.2             0.600         0.08             2.0
# 1595   1595            5.9             0.550         0.10             2.2
# 1596   1596            6.3             0.510         0.13             2.3
# 1597   1597            5.9             0.645         0.12             2.0
# 1598   1598            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.076                 11.0                  34.0  0.99780  3.51
# 1         0.098                 25.0                  67.0  0.99680  3.20
# 2         0.092                 15.0                  54.0  0.99700  3.26
# 3         0.075                 17.0                  60.0  0.99800  3.16
# 4         0.076                 11.0                  34.0  0.99780  3.51
# ...         ...                  ...                   ...      ...   ...
# 1594      0.090                 32.0                  44.0  0.99490  3.45
# 1595      0.062                 39.0                  51.0  0.99512  3.52
# 1596      0.076                 29.0                  40.0  0.99574  3.42
# 1597      0.075                 32.0                  44.0  0.99547  3.57
# 1598      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 0          0.56      9.4        5
# 1          0.68      9.8        5
# 2          0.65      9.8        5
# 3          0.58      9.8        6
# 4          0.56      9.4        5
# ...         ...      ...      ...
# 1594       0.58     10.5        5
# 1595       0.76     11.2        6
# 1596       0.75     11.0        6
# 1597       0.71     10.2        5
# 1598       0.66     11.0        6
#
# [1599 rows x 13 columns]

# %%
df.dtypes
# Out:
# index                     int64
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object
